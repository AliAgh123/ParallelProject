# %% [markdown]
# # Parallel Project
#
# Done by Mohammad Hammoud - Mohammad Jaafar Farhat - Ali Abdel Ghaffar
#
# ## Check gpu

# %%
# !nvidia-smi
# Out:
# Tue May 21 17:09:52 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   55C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# ## Clone the codes

# %%
# !git clone https://github.com/AliAgh123/ParallelProject.git
# Out:
# Cloning into 'ParallelProject'...
# remote: Enumerating objects: 246, done.
# remote: Counting objects: 100% (246/246), done.
# remote: Compressing objects: 100% (178/178), done.
# remote: Total 246 (delta 123), reused 168 (delta 55), pack-reused 0
# Receiving objects: 100% (246/246), 433.63 KiB | 1.70 MiB/s, done.
# Resolving deltas: 100% (123/123), done.

# %%
# %cd ParallelProject
# Out:
# /content/ParallelProject

# %%
# !ls
# Out:
#  bits		     DLXCuda.cu      main.cpp				 Projectppt_template.pptx
#  cmake-build-debug   DLX.h	     MPI_DLX_withoutClass.cpp		 README.md
#  CMakeLists.txt      DLXMpi.cpp     'Parallel Programming Project.pdf'	 Sequential.cpp
#  DLX.cpp	     DLXOpenMp.cpp   ProjectOpenACC.cpp			 sudokuGen.cpp

# %% [markdown]
# ## Running Sudoku Generator
# Run the generator to create multiple sudokus for testing

# %%
# !g++ -o sudokuGenerator.out sudokuGen.cpp

# %%
# !./sudokuGenerator.out
# Out:
# Enter the size of each puzzle (n): 16
# Enter the number of Sudoku puzzles (k): 10
# Sudoku puzzles generated and stored in sudoku_puzzles.txt file.

# %% [markdown]
# ## Sequential Code
# Run the sequential code to check its time

# %%
# !g++ -o sequential.out DLX.cpp Sequential.cpp

# %%
# !./sequential.out
# Out:
# Sudoku puzzles read from file: 10
# +-------------------------------------------------------+
# | 1  2  6  15 | 3  4  5  7  | 8  9  11 10 | 12 13 14 16 |
# | 8  16 12 9  | 2  1  6  10 | 3  4  14 13 | 5  7  15 11 |
# | 11 13 3  7  | 8  12 9  14 | 1  5  15 16 | 6  2  4  10 |
# | 10 5  14 4  | 11 13 15 16 | 2  6  7  12 | 1  3  8  9  |
# |-------------+-------------+-------------+-------------|
# | 2  3  4  5  | 1  6  12 11 | 7  8  16 9  | 10 15 13 14 |
# | 6  1  7  10 | 4  16 14 5  | 13 15 2  11 | 3  8  9  12 |
# | 9  8  11 12 | 15 2  3  13 | 4  10 1  14 | 7  5  16 6  |
# | 13 14 15 16 | 7  9  10 8  | 6  12 3  5  | 11 1  2  4  |
# |-------------+-------------+-------------+-------------|
# | 4  6  1  11 | 9  7  16 15 | 14 2  8  3  | 13 10 12 5  |
# | 3  7  5  8  | 10 14 13 1  | 16 11 12 4  | 15 9  6  2  |
# | 14 15 9  13 | 12 11 2  4  | 5  1  10 6  | 8  16 7  3  |
# | 12 10 16 2  | 5  3  8  6  | 9  7  13 15 | 14 4  11 1  |
# |-------------+-------------+-------------+-------------|
# | 5  4  13 1  | 14 10 11 9  | 15 16 6  7  | 2  12 3  8  |
# | 7  11 8  6  | 16 5  1  3  | 12 13 9  2  | 4  14 10 15 |
# | 15 9  2  3  | 6  8  7  12 | 10 14 4  1  | 16 11 5  13 |
# | 16 12 10 14 | 13 15 4  2  | 11 3  5  8  | 9  6  1  7  |
# +-------------------------------------------------------+
#
#  --> Time Elapsed: 23.971 ms.
#
# solved
# Total Time Elapsed: 24.137 ms.
#
# +-------------------------------------------------------+
# | 3  7  16 15 | 1  2  4  5  | 6  8  9  10 | 11 13 12 14 |
# | 2  14 6  4  | 3  7  8  10 | 1  12 11 13 | 5  9  15 16 |
# | 1  10 8  9  | 11 6  13 12 | 5  14 15 16 | 2  3  4  7  |
# | 13 5  12 11 | 9  14 15 16 | 2  4  3  7  | 1  6  8  10 |
# |-------------+-------------+-------------+-------------|
# | 4  1  3  6  | 5  13 2  9  | 7  10 8  11 | 12 16 14 15 |
# | 5  2  7  8  | 6  3  11 1  | 15 16 14 12 | 4  10 9  13 |
# | 9  16 10 14 | 4  8  12 15 | 13 1  5  2  | 3  7  11 6  |
# | 11 12 15 13 | 7  16 10 14 | 3  6  4  9  | 8  2  5  1  |
# |-------------+-------------+-------------+-------------|
# | 7  4  2  5  | 8  9  14 11 | 10 3  16 6  | 13 15 1  12 |
# | 6  3  1  10 | 12 15 7  13 | 4  11 2  8  | 14 5  16 9  |
# | 8  9  11 12 | 10 1  16 3  | 14 5  13 15 | 7  4  6  2  |
# | 14 15 13 16 | 2  4  5  6  | 9  7  12 1  | 10 11 3  8  |
# |-------------+-------------+-------------+-------------|
# | 10 6  5  3  | 16 12 9  7  | 11 2  1  14 | 15 8  13 4  |
# | 15 8  9  7  | 14 11 1  4  | 16 13 10 3  | 6  12 2  5  |
# | 16 11 14 2  | 13 5  6  8  | 12 15 7  4  | 9  1  10 3  |
# | 12 13 4  1  | 15 10 3  2  | 8  9  6  5  | 16 14 7  11 |
# +-------------------------------------------------------+
#
#  --> Time Elapsed: 21.454 ms.
#
# solved
# Total Time Elapsed: 21.624 ms.
#
# +-------------------------------------------------------+
# | 8  13 12 3  | 2  1  5  4  | 6  7  10 9  | 14 11 16 15 |
# | 9  6  15 7  | 3  8  10 11 | 4  1  16 14 | 2  5  12 13 |
# | 4  5  2  11 | 6  14 16 7  | 3  12 15 13 | 1  10 8  9  |
# | 14 10 16 1  | 9  13 12 15 | 8  2  5  11 | 3  4  6  7  |
# |-------------+-------------+-------------+-------------|
# | 1  2  4  5  | 11 3  8  14 | 7  9  12 10 | 13 16 15 6  |
# | 3  8  6  13 | 10 7  9  2  | 15 16 1  4  | 5  14 11 12 |
# | 7  12 9  16 | 15 5  4  13 | 14 6  11 2  | 8  1  10 3  |
# | 10 11 14 15 | 1  12 6  16 | 13 5  8  3  | 7  2  9  4  |
# |-------------+-------------+-------------+-------------|
# | 2  1  3  6  | 5  15 13 10 | 11 4  9  12 | 16 7  14 8  |
# | 5  4  8  9  | 14 16 1  3  | 2  10 7  15 | 12 6  13 11 |
# | 15 16 13 10 | 4  11 7  12 | 5  14 6  8  | 9  3  2  1  |
# | 11 14 7  12 | 8  6  2  9  | 1  3  13 16 | 10 15 4  5  |
# |-------------+-------------+-------------+-------------|
# | 6  9  10 14 | 13 2  15 5  | 12 11 3  7  | 4  8  1  16 |
# | 13 15 11 2  | 7  9  14 1  | 16 8  4  5  | 6  12 3  10 |
# | 12 3  5  8  | 16 4  11 6  | 10 13 14 1  | 15 9  7  2  |
# | 16 7  1  4  | 12 10 3  8  | 9  15 2  6  | 11 13 5  14 |
# +-------------------------------------------------------+
#
#  --> Time Elapsed: 21.108 ms.
#
# solved
# Total Time Elapsed: 21.247 ms.
#
# +-------------------------------------------------------+
# | 14 15 7  16 | 1  3  2  4  | 5  6  8  9  | 10 13 11 12 |
# | 10 3  8  9  | 6  5  7  11 | 2  1  13 12 | 4  14 15 16 |
# | 5  1  4  2  | 8  10 12 13 | 11 14 15 16 | 3  6  7  9  |
# | 11 6  12 13 | 9  14 16 15 | 3  4  10 7  | 1  2  8  5  |
# |-------------+-------------+-------------+-------------|
# | 1  2  3  5  | 10 9  4  16 | 6  7  11 8  | 12 15 13 14 |
# | 4  8  6  10 | 3  2  15 7  | 12 5  14 13 | 11 16 9  1  |
# | 7  9  13 12 | 5  6  11 14 | 10 15 16 1  | 2  8  3  4  |
# | 15 11 16 14 | 13 12 1  8  | 4  9  2  3  | 6  5  10 7  |
# |-------------+-------------+-------------+-------------|
# | 2  5  9  3  | 7  8  6  12 | 1  11 4  15 | 16 10 14 13 |
# | 6  7  1  11 | 14 13 3  10 | 16 2  12 5  | 8  9  4  15 |
# | 13 16 15 8  | 4  11 5  2  | 14 3  9  10 | 7  1  12 6  |
# | 12 10 14 4  | 15 16 9  1  | 13 8  7  6  | 5  3  2  11 |
# |-------------+-------------+-------------+-------------|
# | 3  4  5  1  | 12 15 10 9  | 8  13 6  11 | 14 7  16 2  |
# | 16 13 2  7  | 11 1  14 3  | 15 10 5  4  | 9  12 6  8  |
# | 8  12 11 6  | 2  7  13 5  | 9  16 3  14 | 15 4  1  10 |
# | 9  14 10 15 | 16 4  8  6  | 7  12 1  2  | 13 11 5  3  |
# +-------------------------------------------------------+
#
#  --> Time Elapsed: 21.359 ms.
#
# solved
# Total Time Elapsed: 21.504 ms.
#
# +-------------------------------------------------------+
# | 13 2  4  15 | 1  5  3  6  | 7  8  9  11 | 10 12 14 16 |
# | 16 3  8  10 | 4  2  9  7  | 1  5  12 14 | 6  11 13 15 |
# | 9  1  14 7  | 8  10 12 11 | 6  15 13 16 | 2  3  4  5  |
# | 5  12 6  11 | 15 13 16 14 | 2  3  10 4  | 1  8  7  9  |
# |-------------+-------------+-------------+-------------|
# | 1  4  2  3  | 14 8  10 16 | 9  6  5  12 | 7  15 11 13 |
# | 8  5  9  12 | 6  15 7  4  | 10 2  11 13 | 3  1  16 14 |
# | 6  11 13 14 | 2  3  1  12 | 15 16 7  8  | 5  9  10 4  |
# | 7  10 15 16 | 13 11 5  9  | 14 4  1  3  | 8  2  6  12 |
# |-------------+-------------+-------------+-------------|
# | 2  6  1  4  | 5  7  8  15 | 11 9  14 10 | 13 16 12 3  |
# | 3  7  5  13 | 9  1  11 10 | 4  12 16 15 | 14 6  8  2  |
# | 10 15 11 8  | 12 16 14 13 | 3  1  2  6  | 9  4  5  7  |
# | 12 14 16 9  | 3  4  6  2  | 5  13 8  7  | 11 10 15 1  |
# |-------------+-------------+-------------+-------------|
# | 4  8  7  1  | 10 9  15 5  | 12 14 6  2  | 16 13 3  11 |
# | 15 16 3  5  | 7  6  2  8  | 13 11 4  9  | 12 14 1  10 |
# | 11 13 12 2  | 16 14 4  1  | 8  10 3  5  | 15 7  9  6  |
# | 14 9  10 6  | 11 12 13 3  | 16 7  15 1  | 4  5  2  8  |
# +-------------------------------------------------------+
#
#  --> Time Elapsed: 21.45 ms.
#
# solved
# Total Time Elapsed: 21.594 ms.
#
# +-------------------------------------------------------+
# | 1  10 13 3  | 2  4  5  6  | 7  8  9  11 | 12 15 14 16 |
# | 14 8  15 16 | 1  3  7  9  | 2  4  12 5  | 6  13 10 11 |
# | 9  7  6  12 | 8  10 11 13 | 1  14 15 16 | 2  4  3  5  |
# | 11 4  5  2  | 12 14 15 16 | 3  6  13 10 | 1  8  9  7  |
# |-------------+-------------+-------------+-------------|
# | 3  5  4  6  | 9  7  2  1  | 10 11 16 8  | 14 12 13 15 |
# | 2  1  9  10 | 13 16 8  11 | 12 15 3  14 | 4  5  7  6  |
# | 7  11 12 14 | 6  15 10 3  | 5  13 4  9  | 8  1  16 2  |
# | 8  13 16 15 | 14 5  4  12 | 6  2  1  7  | 3  9  11 10 |
# |-------------+-------------+-------------+-------------|
# | 5  2  1  7  | 3  8  9  14 | 4  16 11 12 | 10 6  15 13 |
# | 4  6  3  9  | 5  1  13 2  | 8  10 7  15 | 11 16 12 14 |
# | 10 15 14 11 | 4  12 16 7  | 9  1  6  13 | 5  2  8  3  |
# | 12 16 8  13 | 10 11 6  15 | 14 5  2  3  | 9  7  1  4  |
# |-------------+-------------+-------------+-------------|
# | 6  9  11 5  | 15 13 14 8  | 16 12 10 4  | 7  3  2  1  |
# | 13 12 7  1  | 16 2  3  4  | 11 9  14 6  | 15 10 5  8  |
# | 16 3  10 4  | 11 9  1  5  | 15 7  8  2  | 13 14 6  12 |
# | 15 14 2  8  | 7  6  12 10 | 13 3  5  1  | 16 11 4  9  |
# +-------------------------------------------------------+
#
#  --> Time Elapsed: 21.219 ms.
#
# solved
# Total Time Elapsed: 21.368 ms.
#
# +-------------------------------------------------------+
# | 14 11 15 13 | 1  3  2  4  | 5  6  7  9  | 10 8  12 16 |
# | 1  9  10 2  | 6  5  7  8  | 3  4  16 12 | 11 13 15 14 |
# | 7  5  8  6  | 9  12 16 10 | 11 13 15 14 | 1  3  2  4  |
# | 3  16 12 4  | 11 14 13 15 | 1  8  2  10 | 6  7  9  5  |
# |-------------+-------------+-------------+-------------|
# | 2  1  3  7  | 5  4  8  16 | 10 9  6  11 | 14 15 13 12 |
# | 4  6  5  8  | 7  13 15 1  | 12 14 3  2  | 9  16 10 11 |
# | 11 12 13 14 | 3  10 6  9  | 7  16 4  15 | 2  5  1  8  |
# | 9  10 16 15 | 14 2  11 12 | 8  5  1  13 | 3  4  7  6  |
# |-------------+-------------+-------------+-------------|
# | 5  2  4  11 | 8  15 12 7  | 9  1  10 3  | 16 14 6  13 |
# | 6  3  1  9  | 2  16 4  11 | 13 7  14 8  | 15 12 5  10 |
# | 8  13 7  16 | 10 1  9  14 | 6  15 12 5  | 4  11 3  2  |
# | 10 15 14 12 | 13 6  3  5  | 4  2  11 16 | 7  9  8  1  |
# |-------------+-------------+-------------+-------------|
# | 13 4  6  1  | 15 8  14 2  | 16 3  5  7  | 12 10 11 9  |
# | 12 7  9  3  | 16 11 1  13 | 2  10 8  4  | 5  6  14 15 |
# | 15 8  11 5  | 4  7  10 6  | 14 12 9  1  | 13 2  16 3  |
# | 16 14 2  10 | 12 9  5  3  | 15 11 13 6  | 8  1  4  7  |
# +-------------------------------------------------------+
#
#  --> Time Elapsed: 21.36 ms.
#
# solved
# Total Time Elapsed: 21.525 ms.
#
# +-------------------------------------------------------+
# | 11 7  13 16 | 1  2  3  5  | 6  4  8  9  | 10 12 14 15 |
# | 10 1  15 8  | 4  7  6  11 | 2  3  14 12 | 5  9  16 13 |
# | 14 2  6  9  | 10 8  13 12 | 1  16 5  15 | 3  4  11 7  |
# | 5  12 3  4  | 9  15 14 16 | 7  10 13 11 | 1  2  8  6  |
# |-------------+-------------+-------------+-------------|
# | 1  3  2  5  | 16 14 12 9  | 10 6  4  7  | 8  15 13 11 |
# | 6  8  7  10 | 3  5  15 4  | 9  13 11 16 | 2  1  12 14 |
# | 4  11 16 13 | 8  1  2  10 | 3  12 15 14 | 6  7  5  9  |
# | 9  14 12 15 | 11 6  7  13 | 5  1  2  8  | 16 10 3  4  |
# |-------------+-------------+-------------+-------------|
# | 2  5  8  11 | 12 9  10 14 | 4  7  6  3  | 13 16 15 1  |
# | 7  4  1  6  | 13 11 8  15 | 16 5  9  2  | 12 14 10 3  |
# | 13 15 9  12 | 2  3  16 6  | 14 11 1  10 | 7  8  4  5  |
# | 16 10 14 3  | 5  4  1  7  | 8  15 12 13 | 11 6  9  2  |
# |-------------+-------------+-------------+-------------|
# | 3  9  10 2  | 7  13 11 8  | 15 14 16 6  | 4  5  1  12 |
# | 15 16 4  7  | 14 12 5  2  | 11 8  3  1  | 9  13 6  10 |
# | 8  13 11 14 | 6  10 4  1  | 12 9  7  5  | 15 3  2  16 |
# | 12 6  5  1  | 15 16 9  3  | 13 2  10 4  | 14 11 7  8  |
# +-------------------------------------------------------+
#
#  --> Time Elapsed: 21 ms.
#
# solved
# Total Time Elapsed: 21.13 ms.
#
# +-------------------------------------------------------+
# | 14 9  10 15 | 1  2  3  5  | 4  6  7  8  | 11 12 16 13 |
# | 11 7  6  12 | 4  8  9  10 | 1  2  16 13 | 5  3  14 15 |
# | 1  13 8  2  | 6  11 16 12 | 3  5  14 15 | 7  4  9  10 |
# | 4  3  5  16 | 7  14 13 15 | 9  10 11 12 | 2  6  8  1  |
# |-------------+-------------+-------------+-------------|
# | 2  1  4  5  | 14 13 11 3  | 6  9  8  10 | 12 15 7  16 |
# | 3  8  9  10 | 2  6  15 7  | 5  12 1  16 | 13 11 4  14 |
# | 6  11 15 7  | 10 12 8  16 | 13 3  4  14 | 1  2  5  9  |
# | 12 14 16 13 | 9  1  5  4  | 7  11 15 2  | 8  10 6  3  |
# |-------------+-------------+-------------+-------------|
# | 7  2  12 6  | 8  10 14 13 | 11 1  5  9  | 15 16 3  4  |
# | 5  4  1  3  | 11 15 7  9  | 16 8  13 6  | 10 14 2  12 |
# | 15 16 11 8  | 5  4  12 6  | 2  14 10 3  | 9  13 1  7  |
# | 9  10 13 14 | 3  16 1  2  | 15 7  12 4  | 6  8  11 5  |
# |-------------+-------------+-------------+-------------|
# | 8  5  2  1  | 13 7  4  14 | 10 15 3  11 | 16 9  12 6  |
# | 13 12 3  11 | 15 5  6  8  | 14 16 9  1  | 4  7  10 2  |
# | 16 6  14 4  | 12 9  10 1  | 8  13 2  7  | 3  5  15 11 |
# | 10 15 7  9  | 16 3  2  11 | 12 4  6  5  | 14 1  13 8  |
# +-------------------------------------------------------+
#
#  --> Time Elapsed: 21.331 ms.
#
# solved
# Total Time Elapsed: 21.468 ms.
#
# +-------------------------------------------------------+
# | 12 2  10 5  | 1  3  4  7  | 6  8  9  11 | 13 14 16 15 |
# | 11 13 15 4  | 2  5  6  8  | 1  3  16 14 | 7  9  12 10 |
# | 7  6  9  14 | 10 11 12 16 | 2  4  13 15 | 1  3  5  8  |
# | 16 3  8  1  | 13 9  14 15 | 5  10 7  12 | 2  6  4  11 |
# |-------------+-------------+-------------+-------------|
# | 1  4  3  6  | 12 8  13 2  | 7  5  10 9  | 14 15 11 16 |
# | 2  8  11 9  | 14 7  15 5  | 3  16 1  6  | 4  12 10 13 |
# | 13 12 14 16 | 9  1  10 6  | 4  11 15 8  | 3  5  7  2  |
# | 5  10 7  15 | 4  16 11 3  | 13 14 12 2  | 6  8  1  9  |
# |-------------+-------------+-------------+-------------|
# | 3  1  4  7  | 6  12 16 11 | 9  2  14 13 | 15 10 8  5  |
# | 6  9  2  8  | 15 10 1  13 | 12 7  5  4  | 11 16 3  14 |
# | 10 11 16 12 | 5  4  7  14 | 8  15 6  3  | 9  13 2  1  |
# | 14 15 5  13 | 3  2  8  9  | 10 1  11 16 | 12 7  6  4  |
# |-------------+-------------+-------------+-------------|
# | 4  5  1  3  | 11 6  9  12 | 15 13 8  10 | 16 2  14 7  |
# | 15 7  13 2  | 16 14 3  10 | 11 12 4  5  | 8  1  9  6  |
# | 9  14 12 11 | 8  15 5  1  | 16 6  2  7  | 10 4  13 3  |
# | 8  16 6  10 | 7  13 2  4  | 14 9  3  1  | 5  11 15 12 |
# +-------------------------------------------------------+
#
#  --> Time Elapsed: 21.12 ms.
#
# solved
# Total Time Elapsed: 21.277 ms.
#
# done solving
# -------------------------------------------------
# To solve all puzzles: 217 ms.

# %% [markdown]
# ## MPI implementation

# %%
# !mpic++ -o DLXMpi.out DLXMpi.cpp DLX.cpp

# %%
# !mpirun --oversubscribe -np 4 --allow-run-as-root DLXMpi.out
# Out:
# Sudoku puzzles read from file: 10
# Sudoku puzzles read from file: 10
# Sudoku puzzles read from file: 10
# Sudoku puzzles read from file: 10
# +-------------------------------------------------------+
# | 14 11 15 13 | 1  3  2  4  | 5  6  7  9  | 10 8  12 16 |
# | 1  9  10 2  | 6  5  7  8  | 3  4  16 12 | 11 13 15 14 |
# | 7  5  8  6  | 9  12 16 10 | 11 13 15 14 | 1  3  2  4  |
# | 3  16 12 4  | 11 14 13 15 | 1  8  2  10 | 6  7  9  5  |
# |-------------+-------------+-------------+-------------|
# | 2  1  3  7  | 5  4  8  16 | 10 9  6  11 | 14 15 13 12 |
# | 4  6  5  8  | 7  13 15 1  | 12 14 3  2  | 9  16 10 11 |
# | 11 12 13 14 | 3  10 6  9  | 7  16 4  15 | 2  5  1  8  |
# | 9  10 16 15 | 14 2  11 12 | 8  5  1  13 | 3  4  7  6  |
# |-------------+-------------+-------------+-------------|
# | 5  2  4  11 | 8  15 12 7  | 9  1  10 3  | 16 14 6  13 |
# | 6  3  1  9  | 2  16 4  11 | 13 7  14 8  | 15 12 5  10 |
# | 8  13 7  16 | 10 1  9  14 | 6  15 12 5  | 4  11 3  2  |
# | 10 15 14 12 | 13 6  3  5  | 4  2  11 16 | 7  9  8  1  |
# |-------------+-------------+-------------+-------------|
# | 13 4  6  1  | 15 8  14 2  | 16 3  5  7  | 12 10 11 9  |
# | 12 7  9  3  | 16 11 1  13 | 2  10 8  4  | 5  6  14 15 |
# | 15 8  11 5  | 4  7  10 6  | 14 12 9  1  | 13 2  16 3  |
# | 16 14 2  10 | 12 9  5  3  | 15 11 13 6  | 8  1  4  7  |
# +-------------------------------------------------------+
#
#  --> Time Elapsed: 26.682 ms.
#
# solved
# Total Time Elapsed: 26.891 ms.
#
# +-------------------------------------------------------+
# | 12 2  10 5  | 1  3  4  7  | 6  8  9  11 | 13 14 16 15 |
# | 11 13 15 4  | 2  5  6  8  | 1  3  16 14 | 7  9  12 10 |
# | 7  6  9  14 | 10 11 12 16 | 2  4  13 15 | 1  3  5  8  |
# | 16 3  8  1  | 13 9  14 15 | 5  10 7  12 | 2  6  4  11 |
# |-------------+-------------+-------------+-------------|
# | 1  4  3  6  | 12 8  13 2  | 7  5  10 9  | 14 15 11 16 |
# | 2  8  11 9  | 14 7  15 5  | 3  16 1  6  | 4  12 10 13 |
# | 13 12 14 16 | 9  1  10 6  | 4  11 15 8  | 3  5  7  2  |
# | 5  10 7  15 | 4  16 11 3  | 13 14 12 2  | 6  8  1  9  |
# |-------------+-------------+-------------+-------------|
# | 3  1  4  7  | 6  12 16 11 | 9  2  14 13 | 15 10 8  5  |
# | 6  9  2  8  | 15 10 1  13 | 12 7  5  4  | 11 16 3  14 |
# | 10 11 16 12 | 5  4  7  14 | 8  15 6  3  | 9  13 2  1  |
# | 14 15 5  13 | 3  2  8  9  | 10 1  11 16 | 12 7  6  4  |
# |-------------+-------------+-------------+-------------|
# | 4  5  1  3  | 11 6  9  12 | 15 13 8  10 | 16 2  14 7  |
# | 15 7  13 2  | 16 14 3  10 | 11 12 4  5  | 8  1  9  6  |
# | 9  14 12 11 | 8  15 5  1  | 16 6  2  7  | 10 4  13 3  |
# | 8  16 6  10 | 7  13 2  4  | 14 9  3  1  | 5  11 15 12 |
# +-------------------------------------------------------+
#
#  --> Time Elapsed: 26.583 ms.
#
# solved
# Total Time Elapsed: 26.824 ms.
#
# +-------------------------------------------------------+
# | 14 15 7  16 | 1  3  2  4  | 5  6  8  9  | 10 13 11 12 |
# | 10 3  8  9  | 6  5  7  11 | 2  1  13 12 | 4  14 15 16 |
# | 5  1  4  2  | 8  10 12 13 | 11 14 15 16 | 3  6  7  9  |
# | 11 6  12 13 | 9  14 16 15 | 3  4  10 7  | 1  2  8  5  |
# |-------------+-------------+-------------+-------------|
# | 1  2  3  5  | 10 9  4  16 | 6  7  11 8  | 12 15 13 14 |
# | 4  8  6  10 | 3  2  15 7  | 12 5  14 13 | 11 16 9  1  |
# | 7  9  13 12 | 5  6  11 14 | 10 15 16 1  | 2  8  3  4  |
# | 15 11 16 14 | 13 12 1  8  | 4  9  2  3  | 6  5  10 7  |
# |-------------+-------------+-------------+-------------|
# | 2  5  9  3  | 7  8  6  12 | 1  11 4  15 | 16 10 14 13 |
# | 6  7  1  11 | 14 13 3  10 | 16 2  12 5  | 8  9  4  15 |
# | 13 16 15 8  | 4  11 5  2  | 14 3  9  10 | 7  1  12 6  |
# | 12 10 14 4  | 15 16 9  1  | 13 8  7  6  | 5  3  2  11 |
# |-------------+-------------+-------------+-------------|
# | 3  4  5  1  | 12 15 10 9  | 8  13 6  11 | 14 7  16 2  |
# | 16 13 2  7  | 11 1  14 3  | 15 10 5  4  | 9  12 6  8  |
# | 8  12 11 6  | 2  7  13 5  | 9  16 3  14 | 15 4  1  10 |
# | 9  14 10 15 | 16 4  8  6  | 7  12 1  2  | 13 11 5  3  |
# +-------------------------------------------------------+
#
#  --> Time Elapsed: 26.322 ms.
#
# solved
# Total Time Elapsed: 26.528 ms.
#
# +-------------------------------------------------------+
# | 11 7  13 16 | 1  2  3  5  | 6  4  8  9  | 10 12 14 15 |
# | 10 1  15 8  | 4  7  6  11 | 2  3  14 12 | 5  9  16 13 |
# | 14 2  6  9  | 10 8  13 12 | 1  16 5  15 | 3  4  11 7  |
# | 5  12 3  4  | 9  15 14 16 | 7  10 13 11 | 1  2  8  6  |
# |-------------+-------------+-------------+-------------|
# | 1  3  2  5  | 16 14 12 9  | 10 6  4  7  | 8  15 13 11 |
# | 6  8  7  10 | 3  5  15 4  | 9  13 11 16 | 2  1  12 14 |
# | 4  11 16 13 | 8  1  2  10 | 3  12 15 14 | 6  7  5  9  |
# | 9  14 12 15 | 11 6  7  13 | 5  1  2  8  | 16 10 3  4  |
# |-------------+-------------+-------------+-------------|
# | 2  5  8  11 | 12 9  10 14 | 4  7  6  3  | 13 16 15 1  |
# | 7  4  1  6  | 13 11 8  15 | 16 5  9  2  | 12 14 10 3  |
# | 13 15 9  12 | 2  3  16 6  | 14 11 1  10 | 7  8  4  5  |
# | 16 10 14 3  | 5  4  1  7  | 8  15 12 13 | 11 6  9  2  |
# |-------------+-------------+-------------+-------------|
# | 3  9  10 2  | 7  13 11 8  | 15 14 16 6  | 4  5  1  12 |
# | 15 16 4  7  | 14 12 5  2  | 11 8  3  1  | 9  13 6  10 |
# | 8  13 11 14 | 6  10 4  1  | 12 9  7  5  | 15 3  2  16 |
# | 12 6  5  1  | 15 16 9  3  | 13 2  10 4  | 14 11 7  8  |
# +-------------------------------------------------------+
#
#  --> Time Elapsed: 24.664 ms.
#
# solved
# Total Time Elapsed: 24.852 ms.
#
# +-------------------------------------------------------+
# | 13 2  4  15 | 1  5  3  6  | 7  8  9  11 | 10 12 14 16 |
# | 16 3  8  10 | 4  2  9  7  | 1  5  12 14 | 6  11 13 15 |
# | 9  1  14 7  | 8  10 12 11 | 6  15 13 16 | 2  3  4  5  |
# | 5  12 6  11 | 15 13 16 14 | 2  3  10 4  | 1  8  7  9  |
# |-------------+-------------+-------------+-------------|
# | 1  4  2  3  | 14 8  10 16 | 9  6  5  12 | 7  15 11 13 |
# | 8  5  9  12 | 6  15 7  4  | 10 2  11 13 | 3  1  16 14 |
# | 6  11 13 14 | 2  3  1  12 | 15 16 7  8  | 5  9  10 4  |
# | 7  10 15 16 | 13 11 5  9  | 14 4  1  3  | 8  2  6  12 |
# |-------------+-------------+-------------+-------------|
# | 2  6  1  4  | 5  7  8  15 | 11 9  14 10 | 13 16 12 3  |
# | 3  7  5  13 | 9  1  11 10 | 4  12 16 15 | 14 6  8  2  |
# | 10 15 11 8  | 12 16 14 13 | 3  1  2  6  | 9  4  5  7  |
# | 12 14 16 9  | 3  4  6  2  | 5  13 8  7  | 11 10 15 1  |
# |-------------+-------------+-------------+-------------|
# | 4  8  7  1  | 10 9  15 5  | 12 14 6  2  | 16 13 3  11 |
# | 15 16 3  5  | 7  6  2  8  | 13 11 4  9  | 12 14 1  10 |
# | 11 13 12 2  | 16 14 4  1  | 8  10 3  5  | 15 7  9  6  |
# | 14 9  10 6  | 11 12 13 3  | 16 7  15 1  | 4  5  2  8  |
# +-------------------------------------------------------+
#
#  --> Time Elapsed: 23.686 ms.
#
# solved
# Total Time Elapsed: 23.911 ms.
#
# +-------------------------------------------------------+
# | 14 9  10 15 | 1  2  3  5  | 4  6  7  8  | 11 12 16 13 |
# | 11 7  6  12 | 4  8  9  10 | 1  2  16 13 | 5  3  14 15 |
# | 1  13 8  2  | 6  11 16 12 | 3  5  14 15 | 7  4  9  10 |
# | 4  3  5  16 | 7  14 13 15 | 9  10 11 12 | 2  6  8  1  |
# |-------------+-------------+-------------+-------------|
# | 2  1  4  5  | 14 13 11 3  | 6  9  8  10 | 12 15 7  16 |
# | 3  8  9  10 | 2  6  15 7  | 5  12 1  16 | 13 11 4  14 |
# | 6  11 15 7  | 10 12 8  16 | 13 3  4  14 | 1  2  5  9  |
# | 12 14 16 13 | 9  1  5  4  | 7  11 15 2  | 8  10 6  3  |
# |-------------+-------------+-------------+-------------|
# | 7  2  12 6  | 8  10 14 13 | 11 1  5  9  | 15 16 3  4  |
# | 5  4  1  3  | 11 15 7  9  | 16 8  13 6  | 10 14 2  12 |
# | 15 16 11 8  | 5  4  12 6  | 2  14 10 3  | 9  13 1  7  |
# | 9  10 13 14 | 3  16 1  2  | 15 7  12 4  | 6  8  11 5  |
# |-------------+-------------+-------------+-------------|
# | 8  5  2  1  | 13 7  4  14 | 10 15 3  11 | 16 9  12 6  |
# | 13 12 3  11 | 15 5  6  8  | 14 16 9  1  | 4  7  10 2  |
# | 16 6  14 4  | 12 9  10 1  | 8  13 2  7  | 3  5  15 11 |
# | 10 15 7  9  | 16 3  2  11 | 12 4  6  5  | 14 1  13 8  |
# +-------------------------------------------------------+
#
#  --> Time Elapsed: 24.619 ms.
#
# solved
# Total Time Elapsed: 24.806 ms.
#
# +-------------------------------------------------------+
# | 1  10 13 3  | 2  4  5  6  | 7  8  9  11 | 12 15 14 16 |
# | 14 8  15 16 | 1  3  7  9  | 2  4  12 5  | 6  13 10 11 |
# | 9  7  6  12 | 8  10 11 13 | 1  14 15 16 | 2  4  3  5  |
# | 11 4  5  2  | 12 14 15 16 | 3  6  13 10 | 1  8  9  7  |
# |-------------+-------------+-------------+-------------|
# | 3  5  4  6  | 9  7  2  1  | 10 11 16 8  | 14 12 13 15 |
# | 2  1  9  10 | 13 16 8  11 | 12 15 3  14 | 4  5  7  6  |
# | 7  11 12 14 | 6  15 10 3  | 5  13 4  9  | 8  1  16 2  |
# | 8  13 16 15 | 14 5  4  12 | 6  2  1  7  | 3  9  11 10 |
# |-------------+-------------+-------------+-------------|
# | 5  2  1  7  | 3  8  9  14 | 4  16 11 12 | 10 6  15 13 |
# | 4  6  3  9  | 5  1  13 2  | 8  10 7  15 | 11 16 12 14 |
# | 10 15 14 11 | 4  12 16 7  | 9  1  6  13 | 5  2  8  3  |
# | 12 16 8  13 | 10 11 6  15 | 14 5  2  3  | 9  7  1  4  |
# |-------------+-------------+-------------+-------------|
# | 6  9  11 5  | 15 13 14 8  | 16 12 10 4  | 7  3  2  1  |
# | 13 12 7  1  | 16 2  3  4  | 11 9  14 6  | 15 10 5  8  |
# | 16 3  10 4  | 11 9  1  5  | 15 7  8  2  | 13 14 6  12 |
# | 15 14 2  8  | 7  6  12 10 | 13 3  5  1  | 16 11 4  9  |
# +-------------------------------------------------------+
#
#  --> Time Elapsed: 24.118 ms.
#
# solved
# Total Time Elapsed: 24.292 ms.

# %% [markdown]
# ## OpenMP implementation

# %%
# !g++ -o DLXOpenMp.out -fopenmp DLX.cpp DLXOpenMp.cpp
# !./DLXOpenMp.out
# Out:
# Sudoku puzzles read from file: 10
# +-------------------------------------------------------+
# | 1  2  6  15 | 3  4  5  7  | 8  9  11 10 | 12 13 14 16 |
# | 8  16 12 9  | 2  1  6  10 | 3  4  14 13 | 5  7  15 11 |
# | 11 13 3  7  | 8  12 9  14 | 1  5  15 16 | 6  2  4  10 |
# | 10 5  14 4  | 11 13 15 16 | 2  6  7  12 | 1  3  8  9  |
# |-------------+-------------+-------------+-------------|
# | 2  3  4  5  | 1  6  12 11 | 7  8  16 9  | 10 15 13 14 |
# | 6  1  7  10 | 4  16 14 5  | 13 15 2  11 | 3  8  9  12 |
# | 9  8  11 12 | 15 2  3  13 | 4  10 1  14 | 7  5  16 6  |
# | 13 14 15 16 | 7  9  10 8  | 6  12 3  5  | 11 1  2  4  |
# |-------------+-------------+-------------+-------------|
# | 4  6  1  11 | 9  7  16 15 | 14 2  8  3  | 13 10 12 5  |
# | 3  7  5  8  | 10 14 13 1  | 16 11 12 4  | 15 9  6  2  |
# | 14 15 9  13 | 12 11 2  4  | 5  1  10 6  | 8  16 7  3  |
# | 12 10 16 2  | 5  3  8  6  | 9  7  13 15 | 14 4  11 1  |
# |-------------+-------------+-------------+-------------|
# | 5  4  13 1  | 14 10 11 9  | 15 16 6  7  | 2  12 3  8  |
# | 7  11 8  6  | 16 5  1  3  | 12 13 9  2  | 4  14 10 15 |
# | 15 9  2  3  | 6  8  7  12 | 10 14 4  1  | 16 11 5  13 |
# | 16 12 10 14 | 13 15 4  2  | 11 3  5  8  | 9  6  1  7  |
# +-------------------------------------------------------+
#
#  --> Time Elapsed: 23.623 ms.
#
# solved
# Total Time Elapsed: 23.791 ms.
#
# +-------------------------------------------------------+
# | 3  7  16 15 | 1  2  4  5  | 6  8  9  10 | 11 13 12 14 |
# | 2  14 6  4  | 3  7  8  10 | 1  12 11 13 | 5  9  15 16 |
# | 1  10 8  9  | 11 6  13 12 | 5  14 15 16 | 2  3  4  7  |
# | 13 5  12 11 | 9  14 15 16 | 2  4  3  7  | 1  6  8  10 |
# |-------------+-------------+-------------+-------------|
# | 4  1  3  6  | 5  13 2  9  | 7  10 8  11 | 12 16 14 15 |
# | 5  2  7  8  | 6  3  11 1  | 15 16 14 12 | 4  10 9  13 |
# | 9  16 10 14 | 4  8  12 15 | 13 1  5  2  | 3  7  11 6  |
# | 11 12 15 13 | 7  16 10 14 | 3  6  4  9  | 8  2  5  1  |
# |-------------+-------------+-------------+-------------|
# | 7  4  2  5  | 8  9  14 11 | 10 3  16 6  | 13 15 1  12 |
# | 6  3  1  10 | 12 15 7  13 | 4  11 2  8  | 14 5  16 9  |
# | 8  9  11 12 | 10 1  16 3  | 14 5  13 15 | 7  4  6  2  |
# | 14 15 13 16 | 2  4  5  6  | 9  7  12 1  | 10 11 3  8  |
# |-------------+-------------+-------------+-------------|
# | 10 6  5  3  | 16 12 9  7  | 11 2  1  14 | 15 8  13 4  |
# | 15 8  9  7  | 14 11 1  4  | 16 13 10 3  | 6  12 2  5  |
# | 16 11 14 2  | 13 5  6  8  | 12 15 7  4  | 9  1  10 3  |
# | 12 13 4  1  | 15 10 3  2  | 8  9  6  5  | 16 14 7  11 |
# +-------------------------------------------------------+
#
#  --> Time Elapsed: 21.576 ms.
#
# solved
# Total Time Elapsed: 21.753 ms.
#
# +-------------------------------------------------------+
# | 8  13 12 3  | 2  1  5  4  | 6  7  10 9  | 14 11 16 15 |
# | 9  6  15 7  | 3  8  10 11 | 4  1  16 14 | 2  5  12 13 |
# | 4  5  2  11 | 6  14 16 7  | 3  12 15 13 | 1  10 8  9  |
# | 14 10 16 1  | 9  13 12 15 | 8  2  5  11 | 3  4  6  7  |
# |-------------+-------------+-------------+-------------|
# | 1  2  4  5  | 11 3  8  14 | 7  9  12 10 | 13 16 15 6  |
# | 3  8  6  13 | 10 7  9  2  | 15 16 1  4  | 5  14 11 12 |
# | 7  12 9  16 | 15 5  4  13 | 14 6  11 2  | 8  1  10 3  |
# | 10 11 14 15 | 1  12 6  16 | 13 5  8  3  | 7  2  9  4  |
# |-------------+-------------+-------------+-------------|
# | 2  1  3  6  | 5  15 13 10 | 11 4  9  12 | 16 7  14 8  |
# | 5  4  8  9  | 14 16 1  3  | 2  10 7  15 | 12 6  13 11 |
# | 15 16 13 10 | 4  11 7  12 | 5  14 6  8  | 9  3  2  1  |
# | 11 14 7  12 | 8  6  2  9  | 1  3  13 16 | 10 15 4  5  |
# |-------------+-------------+-------------+-------------|
# | 6  9  10 14 | 13 2  15 5  | 12 11 3  7  | 4  8  1  16 |
# | 13 15 11 2  | 7  9  14 1  | 16 8  4  5  | 6  12 3  10 |
# | 12 3  5  8  | 16 4  11 6  | 10 13 14 1  | 15 9  7  2  |
# | 16 7  1  4  | 12 10 3  8  | 9  15 2  6  | 11 13 5  14 |
# +-------------------------------------------------------+
#
#  --> Time Elapsed: 21.695 ms.
#
# solved
# Total Time Elapsed: 21.858 ms.
#
# +-------------------------------------------------------+
# | 14 15 7  16 | 1  3  2  4  | 5  6  8  9  | 10 13 11 12 |
# | 10 3  8  9  | 6  5  7  11 | 2  1  13 12 | 4  14 15 16 |
# | 5  1  4  2  | 8  10 12 13 | 11 14 15 16 | 3  6  7  9  |
# | 11 6  12 13 | 9  14 16 15 | 3  4  10 7  | 1  2  8  5  |
# |-------------+-------------+-------------+-------------|
# | 1  2  3  5  | 10 9  4  16 | 6  7  11 8  | 12 15 13 14 |
# | 4  8  6  10 | 3  2  15 7  | 12 5  14 13 | 11 16 9  1  |
# | 7  9  13 12 | 5  6  11 14 | 10 15 16 1  | 2  8  3  4  |
# | 15 11 16 14 | 13 12 1  8  | 4  9  2  3  | 6  5  10 7  |
# |-------------+-------------+-------------+-------------|
# | 2  5  9  3  | 7  8  6  12 | 1  11 4  15 | 16 10 14 13 |
# | 6  7  1  11 | 14 13 3  10 | 16 2  12 5  | 8  9  4  15 |
# | 13 16 15 8  | 4  11 5  2  | 14 3  9  10 | 7  1  12 6  |
# | 12 10 14 4  | 15 16 9  1  | 13 8  7  6  | 5  3  2  11 |
# |-------------+-------------+-------------+-------------|
# | 3  4  5  1  | 12 15 10 9  | 8  13 6  11 | 14 7  16 2  |
# | 16 13 2  7  | 11 1  14 3  | 15 10 5  4  | 9  12 6  8  |
# | 8  12 11 6  | 2  7  13 5  | 9  16 3  14 | 15 4  1  10 |
# | 9  14 10 15 | 16 4  8  6  | 7  12 1  2  | 13 11 5  3  |
# +-------------------------------------------------------+
#
#  --> Time Elapsed: 22.002 ms.
#
# solved
# Total Time Elapsed: 22.208 ms.
#
# +-------------------------------------------------------+
# | 13 2  4  15 | 1  5  3  6  | 7  8  9  11 | 10 12 14 16 |
# | 16 3  8  10 | 4  2  9  7  | 1  5  12 14 | 6  11 13 15 |
# | 9  1  14 7  | 8  10 12 11 | 6  15 13 16 | 2  3  4  5  |
# | 5  12 6  11 | 15 13 16 14 | 2  3  10 4  | 1  8  7  9  |
# |-------------+-------------+-------------+-------------|
# | 1  4  2  3  | 14 8  10 16 | 9  6  5  12 | 7  15 11 13 |
# | 8  5  9  12 | 6  15 7  4  | 10 2  11 13 | 3  1  16 14 |
# | 6  11 13 14 | 2  3  1  12 | 15 16 7  8  | 5  9  10 4  |
# | 7  10 15 16 | 13 11 5  9  | 14 4  1  3  | 8  2  6  12 |
# |-------------+-------------+-------------+-------------|
# | 2  6  1  4  | 5  7  8  15 | 11 9  14 10 | 13 16 12 3  |
# | 3  7  5  13 | 9  1  11 10 | 4  12 16 15 | 14 6  8  2  |
# | 10 15 11 8  | 12 16 14 13 | 3  1  2  6  | 9  4  5  7  |
# | 12 14 16 9  | 3  4  6  2  | 5  13 8  7  | 11 10 15 1  |
# |-------------+-------------+-------------+-------------|
# | 4  8  7  1  | 10 9  15 5  | 12 14 6  2  | 16 13 3  11 |
# | 15 16 3  5  | 7  6  2  8  | 13 11 4  9  | 12 14 1  10 |
# | 11 13 12 2  | 16 14 4  1  | 8  10 3  5  | 15 7  9  6  |
# | 14 9  10 6  | 11 12 13 3  | 16 7  15 1  | 4  5  2  8  |
# +-------------------------------------------------------+
#
#  --> Time Elapsed: 22.312 ms.
#
# solved
# Total Time Elapsed: 22.475 ms.
#
# +-------------------------------------------------------+
# | 1  10 13 3  | 2  4  5  6  | 7  8  9  11 | 12 15 14 16 |
# | 14 8  15 16 | 1  3  7  9  | 2  4  12 5  | 6  13 10 11 |
# | 9  7  6  12 | 8  10 11 13 | 1  14 15 16 | 2  4  3  5  |
# | 11 4  5  2  | 12 14 15 16 | 3  6  13 10 | 1  8  9  7  |
# |-------------+-------------+-------------+-------------|
# | 3  5  4  6  | 9  7  2  1  | 10 11 16 8  | 14 12 13 15 |
# | 2  1  9  10 | 13 16 8  11 | 12 15 3  14 | 4  5  7  6  |
# | 7  11 12 14 | 6  15 10 3  | 5  13 4  9  | 8  1  16 2  |
# | 8  13 16 15 | 14 5  4  12 | 6  2  1  7  | 3  9  11 10 |
# |-------------+-------------+-------------+-------------|
# | 5  2  1  7  | 3  8  9  14 | 4  16 11 12 | 10 6  15 13 |
# | 4  6  3  9  | 5  1  13 2  | 8  10 7  15 | 11 16 12 14 |
# | 10 15 14 11 | 4  12 16 7  | 9  1  6  13 | 5  2  8  3  |
# | 12 16 8  13 | 10 11 6  15 | 14 5  2  3  | 9  7  1  4  |
# |-------------+-------------+-------------+-------------|
# | 6  9  11 5  | 15 13 14 8  | 16 12 10 4  | 7  3  2  1  |
# | 13 12 7  1  | 16 2  3  4  | 11 9  14 6  | 15 10 5  8  |
# | 16 3  10 4  | 11 9  1  5  | 15 7  8  2  | 13 14 6  12 |
# | 15 14 2  8  | 7  6  12 10 | 13 3  5  1  | 16 11 4  9  |
# +-------------------------------------------------------+
#
#  --> Time Elapsed: 21.756 ms.
#
# solved
# Total Time Elapsed: 21.907 ms.
#
# +-------------------------------------------------------+
# | 14 11 15 13 | 1  3  2  4  | 5  6  7  9  | 10 8  12 16 |
# | 1  9  10 2  | 6  5  7  8  | 3  4  16 12 | 11 13 15 14 |
# | 7  5  8  6  | 9  12 16 10 | 11 13 15 14 | 1  3  2  4  |
# | 3  16 12 4  | 11 14 13 15 | 1  8  2  10 | 6  7  9  5  |
# |-------------+-------------+-------------+-------------|
# | 2  1  3  7  | 5  4  8  16 | 10 9  6  11 | 14 15 13 12 |
# | 4  6  5  8  | 7  13 15 1  | 12 14 3  2  | 9  16 10 11 |
# | 11 12 13 14 | 3  10 6  9  | 7  16 4  15 | 2  5  1  8  |
# | 9  10 16 15 | 14 2  11 12 | 8  5  1  13 | 3  4  7  6  |
# |-------------+-------------+-------------+-------------|
# | 5  2  4  11 | 8  15 12 7  | 9  1  10 3  | 16 14 6  13 |
# | 6  3  1  9  | 2  16 4  11 | 13 7  14 8  | 15 12 5  10 |
# | 8  13 7  16 | 10 1  9  14 | 6  15 12 5  | 4  11 3  2  |
# | 10 15 14 12 | 13 6  3  5  | 4  2  11 16 | 7  9  8  1  |
# |-------------+-------------+-------------+-------------|
# | 13 4  6  1  | 15 8  14 2  | 16 3  5  7  | 12 10 11 9  |
# | 12 7  9  3  | 16 11 1  13 | 2  10 8  4  | 5  6  14 15 |
# | 15 8  11 5  | 4  7  10 6  | 14 12 9  1  | 13 2  16 3  |
# | 16 14 2  10 | 12 9  5  3  | 15 11 13 6  | 8  1  4  7  |
# +-------------------------------------------------------+
#
#  --> Time Elapsed: 21.984 ms.
#
# solved
# Total Time Elapsed: 22.134 ms.
#
# +-------------------------------------------------------+
# | 11 7  13 16 | 1  2  3  5  | 6  4  8  9  | 10 12 14 15 |
# | 10 1  15 8  | 4  7  6  11 | 2  3  14 12 | 5  9  16 13 |
# | 14 2  6  9  | 10 8  13 12 | 1  16 5  15 | 3  4  11 7  |
# | 5  12 3  4  | 9  15 14 16 | 7  10 13 11 | 1  2  8  6  |
# |-------------+-------------+-------------+-------------|
# | 1  3  2  5  | 16 14 12 9  | 10 6  4  7  | 8  15 13 11 |
# | 6  8  7  10 | 3  5  15 4  | 9  13 11 16 | 2  1  12 14 |
# | 4  11 16 13 | 8  1  2  10 | 3  12 15 14 | 6  7  5  9  |
# | 9  14 12 15 | 11 6  7  13 | 5  1  2  8  | 16 10 3  4  |
# |-------------+-------------+-------------+-------------|
# | 2  5  8  11 | 12 9  10 14 | 4  7  6  3  | 13 16 15 1  |
# | 7  4  1  6  | 13 11 8  15 | 16 5  9  2  | 12 14 10 3  |
# | 13 15 9  12 | 2  3  16 6  | 14 11 1  10 | 7  8  4  5  |
# | 16 10 14 3  | 5  4  1  7  | 8  15 12 13 | 11 6  9  2  |
# |-------------+-------------+-------------+-------------|
# | 3  9  10 2  | 7  13 11 8  | 15 14 16 6  | 4  5  1  12 |
# | 15 16 4  7  | 14 12 5  2  | 11 8  3  1  | 9  13 6  10 |
# | 8  13 11 14 | 6  10 4  1  | 12 9  7  5  | 15 3  2  16 |
# | 12 6  5  1  | 15 16 9  3  | 13 2  10 4  | 14 11 7  8  |
# +-------------------------------------------------------+
#
#  --> Time Elapsed: 21.865 ms.
#
# solved
# Total Time Elapsed: 22.007 ms.
#
# +-------------------------------------------------------+
# | 14 9  10 15 | 1  2  3  5  | 4  6  7  8  | 11 12 16 13 |
# | 11 7  6  12 | 4  8  9  10 | 1  2  16 13 | 5  3  14 15 |
# | 1  13 8  2  | 6  11 16 12 | 3  5  14 15 | 7  4  9  10 |
# | 4  3  5  16 | 7  14 13 15 | 9  10 11 12 | 2  6  8  1  |
# |-------------+-------------+-------------+-------------|
# | 2  1  4  5  | 14 13 11 3  | 6  9  8  10 | 12 15 7  16 |
# | 3  8  9  10 | 2  6  15 7  | 5  12 1  16 | 13 11 4  14 |
# | 6  11 15 7  | 10 12 8  16 | 13 3  4  14 | 1  2  5  9  |
# | 12 14 16 13 | 9  1  5  4  | 7  11 15 2  | 8  10 6  3  |
# |-------------+-------------+-------------+-------------|
# | 7  2  12 6  | 8  10 14 13 | 11 1  5  9  | 15 16 3  4  |
# | 5  4  1  3  | 11 15 7  9  | 16 8  13 6  | 10 14 2  12 |
# | 15 16 11 8  | 5  4  12 6  | 2  14 10 3  | 9  13 1  7  |
# | 9  10 13 14 | 3  16 1  2  | 15 7  12 4  | 6  8  11 5  |
# |-------------+-------------+-------------+-------------|
# | 8  5  2  1  | 13 7  4  14 | 10 15 3  11 | 16 9  12 6  |
# | 13 12 3  11 | 15 5  6  8  | 14 16 9  1  | 4  7  10 2  |
# | 16 6  14 4  | 12 9  10 1  | 8  13 2  7  | 3  5  15 11 |
# | 10 15 7  9  | 16 3  2  11 | 12 4  6  5  | 14 1  13 8  |
# +-------------------------------------------------------+
#
#  --> Time Elapsed: 22.144 ms.
#
# solved
# Total Time Elapsed: 22.288 ms.
#
# +-------------------------------------------------------+
# | 12 2  10 5  | 1  3  4  7  | 6  8  9  11 | 13 14 16 15 |
# | 11 13 15 4  | 2  5  6  8  | 1  3  16 14 | 7  9  12 10 |
# | 7  6  9  14 | 10 11 12 16 | 2  4  13 15 | 1  3  5  8  |
# | 16 3  8  1  | 13 9  14 15 | 5  10 7  12 | 2  6  4  11 |
# |-------------+-------------+-------------+-------------|
# | 1  4  3  6  | 12 8  13 2  | 7  5  10 9  | 14 15 11 16 |
# | 2  8  11 9  | 14 7  15 5  | 3  16 1  6  | 4  12 10 13 |
# | 13 12 14 16 | 9  1  10 6  | 4  11 15 8  | 3  5  7  2  |
# | 5  10 7  15 | 4  16 11 3  | 13 14 12 2  | 6  8  1  9  |
# |-------------+-------------+-------------+-------------|
# | 3  1  4  7  | 6  12 16 11 | 9  2  14 13 | 15 10 8  5  |
# | 6  9  2  8  | 15 10 1  13 | 12 7  5  4  | 11 16 3  14 |
# | 10 11 16 12 | 5  4  7  14 | 8  15 6  3  | 9  13 2  1  |
# | 14 15 5  13 | 3  2  8  9  | 10 1  11 16 | 12 7  6  4  |
# |-------------+-------------+-------------+-------------|
# | 4  5  1  3  | 11 6  9  12 | 15 13 8  10 | 16 2  14 7  |
# | 15 7  13 2  | 16 14 3  10 | 11 12 4  5  | 8  1  9  6  |
# | 9  14 12 11 | 8  15 5  1  | 16 6  2  7  | 10 4  13 3  |
# | 8  16 6  10 | 7  13 2  4  | 14 9  3  1  | 5  11 15 12 |
# +-------------------------------------------------------+
#
#  --> Time Elapsed: 22.985 ms.
#
# solved
# Total Time Elapsed: 23.127 ms.
#
# -------------------------------------------------
# To solve all puzzles: 223.662 ms.

# %% [markdown]
# ## Cuda C implementation
#
# First we need to prepare the environement for running Cuda C

# %%
# !python --version
# !nvcc --version
# !pip install nvcc4jupyter
# %load_ext nvcc4jupyter
# Out:
# Python 3.10.12
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Tue_Aug_15_22:02:13_PDT_2023
# Cuda compilation tools, release 12.2, V12.2.140
# Build cuda_12.2.r12.2/compiler.33191640_0
# Collecting nvcc4jupyter
#   Downloading nvcc4jupyter-1.2.1-py3-none-any.whl (10 kB)
# Installing collected packages: nvcc4jupyter
# Successfully installed nvcc4jupyter-1.2.1
# Detected platform "Colab". Running its setup...
# Source files will be saved in "/tmp/tmpm3mg_6ud".

# %% [markdown]
# Then we can start coding

# %%
# %%writefile DLXCuda.cu
# #include <iostream>
# #include <string>
# #include <ctime>
# #include <fstream>
# #include <vector>
# #include <sstream>
# #include <cmath>
#
#
# using namespace std;
#
# __device__ const int MAX_K = 1000;
#
# //#define SIZE 25
# __device__ const int SIZE = 16;
# //#define SIZE 9
# //#define SIZE 4
#
# __device__ const int UNASSIGNED = 0;
#
# // Define the type for a single Sudoku puzzle (2D array)
# typedef vector<vector<int>> SudokuPuzzle;
#
#
# struct Node {
#
#     Node *left;
#     Node *right;
#     Node *up;
#     Node *down;
#     Node *head;
#
#     int size;		//used for Column header
#     int rowID[3];	//used to identify row in order to map solutions to a sudoku grid
#     //ID Format: (Candidate, Row, Column)
# };
#
# __device__ const int SIZE_SQUARED = SIZE*SIZE;
# __device__ const int SIZE_SQRT = sqrt((double)SIZE);
# __device__ const int ROW_NB = SIZE*SIZE*SIZE;
# __device__ const int COL_NB = 4 * SIZE*SIZE;
#
# __device__ struct Node Head;
# __device__ struct Node* HeadNode = &Head;
# __device__ struct Node* solution[MAX_K];
# __device__ struct Node* orig_values[MAX_K];
# __device__ bool matrix[ROW_NB][COL_NB] = { { 0 } };
# __device__ bool isSolved = false;
# __device__ void MapSolutionToGrid(int Sudoku[][SIZE]);
# __device__ void PrintGrid(int Sudoku[][SIZE]);
#
# __device__ clock_t timer, timer2;
#
# // Function to read Sudoku puzzles from file
# vector<SudokuPuzzle> readSudokuPuzzlesFromFile(const string& filename) {
#     ifstream inFile(filename);
#     vector<SudokuPuzzle> puzzles;
#     if (!inFile.is_open()) {
#         cerr << "Error: Unable to open file." << endl;
#         return puzzles;
#     }
#     string line;
#     while (getline(inFile, line)) {
#         int i = 0;
#         SudokuPuzzle puzzle(SIZE, vector<int>(SIZE, UNASSIGNED));
#         while(i < SIZE){
#             stringstream ss(line);
#             for (int j = 0; j < SIZE; ++j) {
#                 ss >> puzzle[i][j];
#             }
#             getline(inFile, line);
#             i++;
#         }
#         puzzles.push_back(puzzle);
#     }
#     inFile.close();
#     return puzzles;
# }
#
#
# //===============================================================================================================//
# //---------------------------------------------DLX Functions-----------------------------------------------------//
# //===============================================================================================================//
#
# __device__ void coverColumn(Node* col) {
#     col->left->right = col->right;
#     col->right->left = col->left;
#     for (Node* node = col->down; node != col; node = node->down) {
#         for (Node* temp = node->right; temp != node; temp = temp->right) {
#             temp->down->up = temp->up;
#             temp->up->down = temp->down;
#             temp->head->size--;
#         }
#     }
# }
#
# __device__ void uncoverColumn(Node* col) {
#     for (Node* node = col->up; node != col; node = node->up) {
#         for (Node* temp = node->left; temp != node; temp = temp->left) {
#             temp->head->size++;
#             temp->down->up = temp;
#             temp->up->down = temp;
#         }
#     }
#     col->left->right = col;
#     col->right->left = col;
# }
#
# __device__ void search(int k) {
#
#     if (HeadNode->right == HeadNode) {
#         timer2 = clock() - timer;
#         int Grid[SIZE][SIZE] = { {0} };
#         MapSolutionToGrid(Grid);
#         PrintGrid(Grid);
#         cout << " --> Time Elapsed: " << (float)timer2 * 1000.0 / CLOCKS_PER_SEC << " ms.\n\n";
#         timer = clock();
#         isSolved = true;
#         return;
#     }
#
#     //Choose Column Object Deterministically: Choose the column with the smallest Size
#     Node* Col = HeadNode->right;
#     for (Node* temp = Col->right; temp != HeadNode; temp = temp->right)
#         if (temp->size < Col->size)
#             Col = temp;
#
#     coverColumn(Col);
#
#     for (Node* temp = Col->down; temp != Col; temp = temp->down) {
#         solution[k] = temp;
#         for (Node* node = temp->right; node != temp; node = node->right) {
#             coverColumn(node->head);
#         }
#
#         search(k + 1);
#
#         temp = solution[k];
#         solution[k] = NULL;
#         Col = temp->head;
#         for (Node* node = temp->left; node != temp; node = node->left) {
#             uncoverColumn(node->head);
#         }
#     }
#
#     uncoverColumn(Col);
# }
#
# //===============================================================================================================//
# //----------------------Functions to turn a Sudoku grid into an Exact Cover problem -----------------------------//
# //===============================================================================================================//
#
# //--------------------------BUILD THE INITIAL MATRIX CONTAINING ALL POSSIBILITIES--------------------------------//
#
# __device__ void BuildSparseMatrix(bool matrix[ROW_NB][COL_NB]) {
#
#     //Constraint 1: There can only be one value in any given cell --> row-column  relation (intersection between the rows and columns
#     int j = 0, counter = 0;
#     for (int i = 0; i < ROW_NB; i++) { //iterate over all rows
#         matrix[i][j] = 1;
#         counter++;
#         if (counter >= SIZE) {
#             j++;
#             counter = 0;
#         }
#     }
#
#     //Constraint 2: There can only be one instance of a number in any given row --> row-number relation (R1#1 R1#2 .... R4#4 ..)
#     int x = 0;
#     counter = 1;
#     for (j = SIZE_SQUARED; j < 2 * SIZE_SQUARED; j++) {
#         for (int i = x; i < counter*SIZE_SQUARED; i += SIZE)
#             matrix[i][j] = 1;
#
#         if ((j + 1) % SIZE == 0) {
#             x = counter*SIZE_SQUARED;
#             counter++;
#         }
#         else
#             x++;
#     }
#
#     //Constraint 3: There can only be one instance of a number in any given column --> column-number relation (C1#1 C1#2 .... C4#4)
#     j = 2 * SIZE_SQUARED;
#     for (int i = 0; i < ROW_NB; i++)
#     {
#         matrix[i][j] = 1;
#         j++;
#         if (j >= 3 * SIZE_SQUARED)
#             j = 2 * SIZE_SQUARED;
#     }
#
#     //Constraint 4: There can only be one instance of a number in any given region --> box-number relation (B1#1 B1#2 ... B4#4)
#     x = 0;
#     for (j = 3 * SIZE_SQUARED; j < COL_NB; j++) {
#
#         for (int l = 0; l < SIZE_SQRT; l++) {
#             for (int k = 0; k<SIZE_SQRT; k++)
#                 matrix[x + l*SIZE + k*SIZE_SQUARED][j] = 1;
#         }
#
#         int temp = j + 1 - 3 * SIZE_SQUARED;
#
#         if (temp % (int)(SIZE_SQRT * SIZE) == 0)
#             x += (SIZE_SQRT - 1)*SIZE_SQUARED + (SIZE_SQRT - 1)*SIZE + 1;
#         else if (temp % SIZE == 0)
#             x += SIZE*(SIZE_SQRT - 1) + 1;
#         else
#             x++;
#     }
# }
#
# //-------------------BUILD A TOROIDAL DOUBLY LINKED LIST OUT OF THE SPARSE MATRIX-------------------------//
#
# __device__ void BuildLinkedList(bool matrix[ROW_NB][COL_NB]) {
#
#     Node* header = new Node;
#     header->left = header;
#     header->right = header;
#     header->down = header;
#     header->up = header;
#     header->size = -1;
#     header->head = header;
#     Node* temp = header;
#
#     //Create all Column Nodes
#     for (int i = 0; i < COL_NB; i++) {
#         Node* newNode = new Node;
#         newNode->size = 0;
#         newNode->up = newNode;
#         newNode->down = newNode;
#         newNode->head = newNode;
#         newNode->right = header;
#         newNode->left = temp;
#         temp->right = newNode;
#         temp = newNode;
#     }
#
#     int ID[3] = { 0,1,1 }; // (candidate, row, column)
#     //Add a Node for each 1 present in the sparse matrix and update Column Nodes accordingly
#     for (int i = 0; i < ROW_NB; i++) {
#         Node* top = header->right;
#         Node* prev = NULL;
#
#         if (i != 0 && i%SIZE_SQUARED == 0) {
#             ID[0] -= SIZE - 1;
#             ID[1]++;
#             ID[2] -= SIZE - 1;
#         }
#         else if (i!= 0 && i%SIZE == 0) {
#             ID[0] -= SIZE - 1;
#             ID[2]++;
#         }
#         else {
#             ID[0]++;
#         }
#
#         for (int j = 0; j < COL_NB; j++, top = top->right) {
#             if (matrix[i][j]) {
#                 Node* newNode = new Node;
#                 newNode->rowID[0] = ID[0];
#                 newNode->rowID[1] = ID[1];
#                 newNode->rowID[2] = ID[2];
#                 if (prev == NULL) {
#                     prev = newNode;
#                     prev->right = newNode;
#                 }
#                 newNode->left = prev;
#                 newNode->right = prev->right;
#                 newNode->right->left = newNode;
#                 prev->right = newNode;
#                 newNode->head = top;
#                 newNode->down = top;
#                 newNode->up = top->up;
#                 top->up->down = newNode;
#                 top->size++;
#                 top->up = newNode;
#                 if (top->down == top)
#                     top->down = newNode;
#                 prev = newNode;
#             }
#         }
#     }
#
#     HeadNode = header;
# }
#
# //-------------------COVERS VALUES THAT ARE ALREADY PRESENT IN THE GRID-------------------------//
#
# __device__ void TransformListToCurrentGrid(vector<vector<int>> Puzzle) {
#     int index = 0;
#     for(int i = 0 ; i<SIZE; i++ )
#         for(int j = 0 ; j<SIZE; j++)
#             if (Puzzle[i][j] > 0) {
#                 Node* Col = NULL;
#                 Node* temp = NULL;
#                 for (Col = HeadNode->right; Col != HeadNode; Col = Col->right) {
#                     for (temp = Col->down; temp != Col; temp = temp->down)
#                         if (temp->rowID[0] == Puzzle[i][j] && (temp->rowID[1] - 1) == i && (temp->rowID[2] - 1) == j)
#                             goto ExitLoops;
#                 }
#                 ExitLoops:		coverColumn(Col);
#                 orig_values[index] = temp;
#                 index++;
#                 for (Node* node = temp->right; node != temp; node = node->right) {
#                     coverColumn(node->head);
#                 }
#
#             }
#
# }
#
# //===============================================================================================================//
# //----------------------------------------------- Print Functions -----------------------------------------------//
# //===============================================================================================================//
#
# __device__ void MapSolutionToGrid(int Sudoku[][SIZE]) {
#
#     for (int i = 0; solution[i] != NULL; i++) {
#         Sudoku[solution[i]->rowID[1]-1][solution[i]->rowID[2]-1] = solution[i]->rowID[0];
#     }
#     for (int i = 0; orig_values[i] != NULL; i++) {
#         Sudoku[orig_values[i]->rowID[1] - 1][orig_values[i]->rowID[2] - 1] = orig_values[i]->rowID[0];
#     }
# }
#
# //---------------------------------PRINTS A SUDOKU GRID OF ANY SIZE---------------------------------------------//
#
# __device__ void PrintGrid(int Sudoku[][SIZE]){
#     string ext_border = "+", int_border = "|";
#     int counter = 1;
#     int additional = 0;
#     if (SIZE > 9)
#         additional = SIZE;
#     for (int i = 0; i < ((SIZE +SIZE_SQRT - 1) * 2 +additional+ 1); i++) {
#         ext_border += '-';
#
#         if (i > 0 && i % ((SIZE_SQRT*2+SIZE_SQRT*(SIZE>9)+1)*counter + counter-1) == 0) {
#             int_border += '+';
#             counter++;
#         }
#         else
#             int_border += '-';
#     }
#     ext_border += '+';
#     int_border += "|";
#
#     cout << ext_border << endl;
#     for (int i = 0; i<SIZE; i++){
#         cout << "| ";
#         for (int j = 0; j<SIZE; j++){
#             if (Sudoku[i][j] == 0)
#                 cout << ". ";
#             else
#                 cout << Sudoku[i][j] << " ";
#             if (additional > 0 && Sudoku[i][j]<10)
#                 cout << " ";
#             if ((j+1)%SIZE_SQRT == 0)
#                 cout << "| ";
#         }
#         cout << endl;
#         if ((i + 1) % SIZE_SQRT == 0 && (i+1)<SIZE)
#             cout << int_border << endl;
#     }
#     cout << ext_border << endl << endl;
# }
#
# //--------------------------------------------------------------------------------//
#
# __device__ void SolveSudoku(vector<vector<int>> Sudoku) {
#     timer = clock();
#     BuildSparseMatrix(matrix);
#     BuildLinkedList(matrix);
#     TransformListToCurrentGrid(Sudoku);
#     search(0);
#     if (!isSolved)
#         cout << "No Solution!" << endl;
#     isSolved = false;
#     cout << "solved\n";
# }
#
# __device__ void solve(vector<vector<int>> puzzle){
#
#     clock_t totalStart = clock();
#     SolveSudoku(puzzle);
#     clock_t totalEnd = clock() - totalStart;
#     cout << "Total Time Elapsed: " << (float)totalEnd * 1000.0 / CLOCKS_PER_SEC << " ms.\n\n";
#
#     return;
# }
#
#
# __global__ void solveInParallel(SudokuPuzzle* puzzles, int n)
# {
#     int index = blockIdx.y * blockDim.y + threadIdx.y;
#     if(index < n){
#         solve(puzzles[index]);
#     }
# }
#
# int main(){
#
#     int n = 2048;
#
#     string filename = "sudoku_puzzles.txt";
#     vector<SudokuPuzzle> puzzles = readSudokuPuzzlesFromFile(filename);
#     if (puzzles.empty()) {
#         cout << "No Sudoku puzzles found in the file." << endl;
#         return 1;
#     }
#     cout << "Sudoku puzzles read from file: " << puzzles.size() << endl;
#
#     SudokuPuzzle* h_puzzles = new SudokuPuzzle[puzzles.size()];
#
#     // Allocate memory on the device
#     SudokuPuzzle* d_puzzles;
#     cudaMalloc((void**)&d_puzzles, puzzles.size() * sizeof(SudokuPuzzle));
#
#     // Copy puzzles from host to device
#     cudaMemcpy(d_puzzles, h_puzzles, puzzles.size() * sizeof(SudokuPuzzle), cudaMemcpyHostToDevice);
#
#     int threadsPerBlock = 256;
#     int blocksPerGrid = (puzzles.size() + threadsPerBlock - 1) / threadsPerBlock;
#
#     solveInParallel<<<blocksPerGrid, threadsPerBlock>>>(d_puzzles, puzzles.size());
#
#     cudaDeviceSynchronize();
#
#     cudaMemcpy(h_puzzles, d_puzzles, SIZE * SIZE * puzzles.size() * sizeof(int), cudaMemcpyDeviceToHost);
#
#     cudaFree(d_puzzles);
#     cout<<"done solving";
#     return 0;
# }
# Out:
# Overwriting DLXCuda.cu

# %%
# !nvcc DLXCuda.cu DLX.cpp -o DLXCuda.out -diag-suppress 20096 -diag-suppress 177
# Out:
# DLXCuda.cu(39): error: dynamic initialization is not supported for a __device__ variable
#   __attribute__((device)) const int SIZE_SQRT = sqrt((double)SIZE);
#                                     ^
#
# 1 error detected in the compilation of "DLXCuda.cu".
